# %%
print('This is a string {}'.format('INSERTED'))
# Out:
# This is a string INSERTED

# %%
print('The {} {} {}'.format('fox','brown','quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}'.format('fox','brown','quick'))
# Out:
# The quick brown fox

# %%
print('The {0} {0} {0}'.format('fox','brown','quick'))
# Out:
# The fox fox fox

# %%
 print('The {q} {b} {f}'.format(f='fox',b='brown',q='quick'))    #we can assign them keywords also.(variable assignment)
# Out:
# The quick brown fox

# %% [markdown]
# Float formatting with the .format method "{value:width.precision f}"

# %%
result=100/777

# %%
result
# Out:
# 0.1287001287001287

# %%
print("The result was {}".format(result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r}".format(r=result))
# Out:
# The result was 0.1287001287001287

# %%
print("The result was {r:1.3f}".format(r=result))
# Out:
# The result was 0.129

# %%
print("The result was {r:10.3f}".format(r=result))    #width is basically the white space
# Out:
# The result was      0.129

# %%
print("The result was {r:1.5f}".format(r=result))
# Out:
# The result was 0.12870

# %% [markdown]
# f-String: Relatively New

# %%
name ='Jose'

# %%
print('Hello his name is {}'.format(name))
# Out:
# Hello his name is Jose

# %%
print(f'Hello his name is {name}')     #replace .format() with f in front of the string and pass in name directly into string itself
# Out:
# Hello his name is Jose

# %%
name='Sam'
age=3

# %%
print(f'{name} is {age} years old')
# Out:
# Sam is 3 years old
