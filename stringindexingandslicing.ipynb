# %%
mystring="Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-2]
# Out:
# 'l'

# %%
mystring[-3]
# Out:
# 'r'

# %% [markdown]
# Now we ue slicing to get the sub section of the stirng. Usually more than one character

# %%
mystring='abcdefghijk'

# %%
mystring
# Out:
# 'abcdefghijk'

# %%
mystring[2:]
# Out:
# 'cdefghijk'

# %% [markdown]
# The below statement says that go upto index number 3 and not include it therefore we only get abc

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %% [markdown]
# Now we will talk about step size

# %%
mystring[::]
# Out:
# 'abcdefghijk'

# %%
mystring[::2]
# Out:
# 'acegik'

# %%
mystring[::3]
# Out:
# 'adgj'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %% [markdown]
# The below trick reverses the string. We are saying that go from all the way to beginning to all the way to end and take a backward step

# %%
mystring[::-1]
# Out:
# 'kjihgfedcba'
