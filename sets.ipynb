# %% [markdown]
# Sets are unordered collections of unique elements. Meaning there can only be one representative of the same object. No letter or character can be more than one time

# %%
myset=set()

# %%
myset            #empty set right now
# Out:
# set()

# %%
myset.add(1)   #add an object

# %%
myset
# Out:
# {1}

# %%
myset.add(2)

# %%
myset
# Out:
# {1, 2}

# %%
myset.add(2)

# %%
myset         #no repetition since sets only accept unique values
# Out:
# {1, 2}

# %%
mylist=[1,1,1,2,2,2,3,3,3]

# %%
set(mylist)     #they dont have orders associated to them sets like this case.
# Out:
# {1, 2, 3}
