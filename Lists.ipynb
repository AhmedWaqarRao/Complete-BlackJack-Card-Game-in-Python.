# %% [markdown]
# Lists are ordered sequences that can hold a variety of object types. They use [] and commas to separate objects in the list

# %%
my_list=[1,2,3]

# %%
my_list=['String',100,23.2]

# %%
len(my_list)
# Out:
# 3

# %%
mylist=['one','two','three']

# %%
mylist[0]        #indexing
# Out:
# 'one'

# %%
mylist[1:]      #slicing
# Out:
# ['two', 'three']

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
another_list=['four','five']

# %%
mylist+another_list                      #concatenation
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# We are not saving the above concatenated result. So if we call mylist or another_list we will get the original contents of them. If we want to save the result we need to assign the above result to something.

# %%
mylist
# Out:
# ['one', 'two', 'three']

# %%
another_list
# Out:
# ['four', 'five']

# %%
new_list=mylist+another_list

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %% [markdown]
# The functions of lists are quite similar to that of strings. But the lists are mutable i.e they can be changed contrary to strings

# %%
new_list
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_list[0]='ONE ALL CAPS'    #mutate

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
new_list.append('six')              #adds new element to the end of the list

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five', 'six']

# %%
new_list.pop()                #removes the element from the end of the list
# Out:
# 'six'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four', 'five']

# %%
popped_item=new_list.pop()

# %%
popped_item
# Out:
# 'five'

# %%
new_list
# Out:
# ['ONE ALL CAPS', 'two', 'three', 'four']

# %%
new_list.pop(0)       #we can pop at any location using indexing, by default it is -1 the very end of list
# Out:
# 'ONE ALL CAPS'

# %%
new_list
# Out:
# ['two', 'three', 'four']

# %%
new_list=['a','e','x','b','c']
num_list=[4,1,8,3]

# %%
new_list.sort()      #does not return anything

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
num_list.sort()

# %%
num_list
# Out:
# [1, 3, 4, 8]

# %%
num_list.reverse()

# %%
num_list
# Out:
# [8, 4, 3, 1]
