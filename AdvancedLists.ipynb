# %% [markdown]
# # Advanced Lists

# %%
l=[1,2,3]

# %%
l.append(4)

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.count(2)     #counts the occurence of item in a list
# Out:
# 1

# %%
x=[1,2,3]
x.append([4,5])    #what to do if we want to extend this list into our original list. We use extend method as follows
print(x)
# Out:
# [1, 2, 3, [4, 5]]

# %%
x=[1,2,3]
x.extend([4,5])
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.index(3)
# Out:
# 2

# %%
l.insert(2,'inserted')     #put object inserted at the index position 2

# %%
l
# Out:
# [1, 2, 'inserted', 3, 4]

# %%
l.pop()
# Out:
# 4

# %%
l
# Out:
# [1, 2, 'inserted', 3]

# %%
l.pop(0)    #we can also place an index. By deafult it pops the last element of the list
# Out:
# 2

# %%
l
# Out:
# ['inserted', 3]

# %%
l=[1,2,1,4]

# %%
l.remove(1)     #removes first occurence of a value

# %%
l
# Out:
# [2, 1, 4]

# %%
l.reverse()

# %%
l
# Out:
# [4, 1, 2]

# %%
l.sort()     #sort our list in ascending order

# %%
l
# Out:
# [1, 2, 4]
