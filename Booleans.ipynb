# %% [markdown]
# Booleans are operators that allow us to convey true or false statements. They are important with control flow and logic.

# %%
True    #uppercase T
# Out:
# True

# %%
False   #uppercase F
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
1>2      #comparison operators (>,<,==,<=,>= etc)
# Out:
# False

# %%
1==1
# Out:
# True

# %%
b=None          #just a placeholder

# %%
b
