# %%
class SimpleCalculator():
    
    def __init__(self,a,b,result):
        self.a=a
        self.b=b
        self.result=result
        
    def operation(self):
        
        while True:
            print('Which operation do you want to perform? \n')
            operator=input('Enter +,-,/ or *: ')
            if operator not in ['+','-','/','*']:
                print('Enter a valid operation please!')
                continue
            else:
                break
        
        if(operator=='+'):
            self.result=self.a+self.b
            print('The result is: ', self.result)
        
        elif(operator=='-'):
            self.result=self.a-self.b
            print('The result is: ', self.result)
        
        elif(operator=='/'):
            self.result=self.a/self.b
            print('The result is: ', self.result)
        
        else:
            self.result=self.a*self.b
            print('The result is: ', self.result)

# %%
calculation=True
number=1
while calculation:
     
    if(number==1 or decision2.lower()=='n'):
        a=int(input('Enter Number a '))
        b=int(input('Enter Number b '))
        
    else:
        print('Do you want existing result to be number a or b? \n')
        decision3=input('Enter a or b: ')
        
        if(decision3.lower()=='a'):
            a=calc.result
            print('Number a is: ', a)
            b=int(input('Enter Number b '))
            
        else:
            a=int(input('Enter Number a '))
            b=calc.result
            print('Number b is: ', b)
    
    calc=SimpleCalculator(a,b,0)
    calc.operation()
    
    while True:                                                 #I can make individual function of it
        print('Do you want to perform another operation? \n')
        decision=input('Enter y or n: ')
        if decision.lower() not in ['y','n']:
            print('Enter y or n.')
            continue
        else:
            break
        
    if decision.lower()=='n':
        print('Final Result is: ', calc.result)
        break
        
    else:
        while True:                                         #I can make individual function of it
            print('Do you want entirely new calculation or want to use existing result? \n')
            decision2=input('Enter n:New Calculation or e:Existing Calculation: ')
            if decision2.lower() not in ['n','e']:
                print('Enter valid input either n or e.')
                continue
            else:
                break
                
        if decision2.lower()=='n':
            continue
        else:
            number=number+1
            continue
# Out:
# Enter Number a 7
# Enter Number b 8
# Which operation do you want to perform?
#
# Enter +,-,/ or *: *
# The result is:  56
# Do you want to perform another operation?
#
# Enter y or n: y
# Do you want entirely new calculation or want to use existing result?
#
# Enter n:New Calculation or e:Existing Existing: n
# Enter Number a 8
# Enter Number b 4
# Which operation do you want to perform?
#
# Enter +,-,/ or *: /
# The result is:  2.0
# Do you want to perform another operation?
#
# Enter y or n: y
# Do you want entirely new calculation or want to use existing result?
#
# Enter n:New Calculation or e:Existing Existing: e
# Do you want existing result to be number a or b?
#
# Enter a or b: a
# Number a is:  2.0
# Enter Number b 3
# Which operation do you want to perform?
#
# Enter +,-,/ or *: *
# The result is:  6.0
# Do you want to perform another operation?
#
# Enter y or n: y
# Do you want entirely new calculation or want to use existing result?
#
# ...
